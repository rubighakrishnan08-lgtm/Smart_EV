# %%
import pandas as pd

df = pd.read_csv("data/Dataset 2_Hourly EV loads - Per user.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data/Dataset 2_Hourly EV loads - Per user.csv")
#       4 df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
import os
os.listdir("data")
# Out:
# ['.ipynb_checkpoints',
#  'Dataset 1_EV charging reports.csv',
#  'Dataset 2_Hourly EV loads - Per user.csv',
#  'Dataset 3a_Hourly EV loads - Aggregated private.csv',
#  'Dataset 3b_Hourly EV loads - Aggregated shared.csv',
#  'Dataset 5_AMS data from garage Bl2.csv',
#  'Dataset 6_Local traffic distribution.csv',
#  'Norway_Trondheim_ExactLoc_Weather.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb']

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("data/Dataset 2_Hourly EV loads - Per user.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data/Dataset 2_Hourly EV loads - Per user.csv")
#       4 df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df = pd.read_csv(
    "data/Dataset 2_Hourly EV loads - Per user.csv",
    sep=";",
    engine="python"
)

df.head()
# Out:
#           date_from           date_to User_ID  session_ID Synthetic_3_6kW  \
# 0  21.12.2018 10:00  21.12.2018 11:00  AdO3-4         1.0             0,3
# 1  21.12.2018 10:00  21.12.2018 11:00  AdO3-4         2.0            0,87
# 2  21.12.2018 11:00  21.12.2018 12:00  AdO3-4         3.0            1,62
# 3  21.12.2018 12:00  21.12.2018 13:00  AdO3-4         3.0             3,6
# 4  21.12.2018 13:00  21.12.2018 14:00  AdO3-4         3.0             3,6
#
#   Synthetic_7_2kW Flex_3_6kW Flex_7_2kW
# 0             0,3        NaN       0,06
# 1            0,87        NaN      0,114
# 2            3,24        NaN        NaN
# 3             7,2        NaN        NaN
# 4             7,2        NaN        NaN

# %%
# Replace comma with dot and convert to float
cols = ["Synthetic_3_6kW", "Synthetic_7_2kW",
        "Flex_3_6kW", "Flex_7_2kW"]

for col in cols:
    df[col] = df[col].astype(str).str.replace(",", ".")
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Create total load
df["Total_Load"] = df[cols].sum(axis=1)

df.head()
# Out:
#           date_from           date_to User_ID  session_ID  Synthetic_3_6kW  \
# 0  21.12.2018 10:00  21.12.2018 11:00  AdO3-4         1.0             0.30
# 1  21.12.2018 10:00  21.12.2018 11:00  AdO3-4         2.0             0.87
# 2  21.12.2018 11:00  21.12.2018 12:00  AdO3-4         3.0             1.62
# 3  21.12.2018 12:00  21.12.2018 13:00  AdO3-4         3.0             3.60
# 4  21.12.2018 13:00  21.12.2018 14:00  AdO3-4         3.0             3.60
#
#    Synthetic_7_2kW  Flex_3_6kW  Flex_7_2kW  Total_Load
# 0             0.30         NaN       0.060       0.660
# 1             0.87         NaN       0.114       1.854
# 2             3.24         NaN         NaN       4.860
# 3             7.20         NaN         NaN      10.800
# 4             7.20         NaN         NaN      10.800

# %%
df["date_from"] = pd.to_datetime(df["date_from"], dayfirst=True)

df["hour"] = df["date_from"].dt.hour
df["day"] = df["date_from"].dt.day
df["month"] = df["date_from"].dt.month

# %%
df["date_from"] = pd.to_datetime(df["date_from"], dayfirst=True)

df["hour"] = df["date_from"].dt.hour
df["day"] = df["date_from"].dt.day
df["month"] = df["date_from"].dt.month

# %%
df["date_from"] = pd.to_datetime(df["date_from"], dayfirst=True)

df["hour"] = df["date_from"].dt.hour
df["day"] = df["date_from"].dt.day
df["month"] = df["date_from"].dt.month

# %%
df["date_from"] = pd.to_datetime(df["date_from"], dayfirst=True)

df["hour"] = df["date_from"].dt.hour
df["day"] = df["date_from"].dt.day
df["month"] = df["date_from"].dt.month
